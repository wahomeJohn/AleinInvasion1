# %% [markdown]
# <a href="https://colab.research.google.com/github/wahomeJohn/AleinInvasion1/blob/main/pandas_ass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DS Homework: Pandas-Seaborn-Matplotlib**
# Design a program in Python to ingest an Excel spreadsheet dataset using Pandas

# %%
import pandas as pd
df = pd.read_csv("/heart.csv")
df
# Out:
#      Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0     40   M           ATA  ...      0.0        Up             0
# 1     49   F           NAP  ...      1.0      Flat             1
# 2     37   M           ATA  ...      0.0        Up             0
# 3     48   F           ASY  ...      1.5      Flat             1
# 4     54   M           NAP  ...      0.0        Up             0
# ..   ...  ..           ...  ...      ...       ...           ...
# 913   45   M            TA  ...      1.2      Flat             1
# 914   68   M           ASY  ...      3.4      Flat             1
# 915   57   M           ASY  ...      1.2      Flat             1
# 916   57   F           ATA  ...      0.0      Flat             1
# 917   38   M           NAP  ...      0.0        Up             0
#
# [918 rows x 12 columns]

# %%
df.shape
# Out:
# (918, 12)

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %% [markdown]
# a) Dropping unwanted columns

# %%
df.drop(['Oldpeak','ST_Slope'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'HeartDisease'],
#       dtype='object')

# %%
df.shape
# Out:
# (918, 10)

# %% [markdown]
# b) Select particular columns while reading the dataset and display a snapshot of the result.

# %%
df[["Age","Sex"]]
# Out:
#      Age Sex
# 0     40   M
# 1     49   F
# 2     37   M
# 3     48   F
# 4     54   M
# ..   ...  ..
# 913   45   M
# 914   68   M
# 915   57   M
# 916   57   F
# 917   38   M
#
# [918 rows x 2 columns]

# %% [markdown]
# c) Read part of the dataframe in terms of rows - just read the first n number of rows

# %%
df = pd.read_csv("/heart.csv", nrows = 20)
df
# Out:
#     Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0    40   M           ATA  ...      0.0        Up             0
# 1    49   F           NAP  ...      1.0      Flat             1
# 2    37   M           ATA  ...      0.0        Up             0
# 3    48   F           ASY  ...      1.5      Flat             1
# 4    54   M           NAP  ...      0.0        Up             0
# 5    39   M           NAP  ...      0.0        Up             0
# 6    45   F           ATA  ...      0.0        Up             0
# 7    54   M           ATA  ...      0.0        Up             0
# 8    37   M           ASY  ...      1.5      Flat             1
# 9    48   F           ATA  ...      0.0        Up             0
# 10   37   F           NAP  ...      0.0        Up             0
# 11   58   M           ATA  ...      2.0      Flat             1
# 12   39   M           ATA  ...      0.0        Up             0
# 13   49   M           ASY  ...      1.0      Flat             1
# ...

# %% [markdown]
# d) After creating a dataframe draw a small sample to work and show the sample of rows
# and columns

# %%
df.sample(n=10)
# Out:
#     Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 14   42   F           NAP  ...      0.0        Up             0
# 13   49   M           ASY  ...      1.0      Flat             1
# 2    37   M           ATA  ...      0.0        Up             0
# 18   60   M           ASY  ...      1.0      Flat             1
# 1    49   F           NAP  ...      1.0      Flat             1
# 12   39   M           ATA  ...      0.0        Up             0
# 17   43   F           ATA  ...      0.0        Up             0
# 15   54   F           ATA  ...      1.5      Flat             0
# 10   37   F           NAP  ...      0.0        Up             0
# 5    39   M           NAP  ...      0.0        Up             0
#
# [10 rows x 12 columns]

# %%
#frac is used  instead of 'n' to tell pandas  the fraction of dataframe you want to be returned 
#replace enables one to select one row more than once
#weight gives a particular row more chances of being selected
#random state ensured persistence
df.sample(frac=2, replace=True, random_state=1)
# Out:
#     Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 5    39   M           NAP  ...      0.0        Up             0
# 11   58   M           ATA  ...      2.0      Flat             1
# 12   39   M           ATA  ...      0.0        Up             0
# 8    37   M           ASY  ...      1.5      Flat             1
# 9    48   F           ATA  ...      0.0        Up             0
# 11   58   M           ATA  ...      2.0      Flat             1
# 5    39   M           NAP  ...      0.0        Up             0
# 15   54   F           ATA  ...      1.5      Flat             0
# 0    40   M           ATA  ...      0.0        Up             0
# 16   38   M           ASY  ...      0.0      Flat             1
# 1    49   F           NAP  ...      1.0      Flat             1
# 12   39   M           ATA  ...      0.0        Up             0
# 7    54   M           ATA  ...      0.0        Up             0
# 13   49   M           ASY  ...      1.0      Flat             1
# ...

# %% [markdown]
# e) Check for the missing value and display those in a snapshot

# %%
df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# f)Add missing values using loc and iloc functions.

# %%
df1= df.fillna("0")
df1 = df.fillna({	'Age':0,
                 'Sex':'Not identified',	
                 'ChestPainType':'Not identified',	
                 'RestingBP':00,	
                 'Cholesterol':'Not identified',
                 'FastingBS':00,
                 'RestingECG':'Not identified',
                 'MaxHR':00,
                 'ExerciseAngina':'Not identified',
                 'Oldpeak':00,
                 'ST_Slope':'Not identified',
                 	'HeartDisease': 00
    
})
df1
# Out:
#     Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0    40   M           ATA  ...      0.0        Up             0
# 1    49   F           NAP  ...      1.0      Flat             1
# 2    37   M           ATA  ...      0.0        Up             0
# 3    48   F           ASY  ...      1.5      Flat             1
# 4    54   M           NAP  ...      0.0        Up             0
# 5    39   M           NAP  ...      0.0        Up             0
# 6    45   F           ATA  ...      0.0        Up             0
# 7    54   M           ATA  ...      0.0        Up             0
# 8    37   M           ASY  ...      1.5      Flat             1
# 9    48   F           ATA  ...      0.0        Up             0
# 10   37   F           NAP  ...      0.0        Up             0
# 11   58   M           ATA  ...      2.0      Flat             1
# 12   39   M           ATA  ...      0.0        Up             0
# 13   49   M           ASY  ...      1.0      Flat             1
# ...

# %% [markdown]
# Select rows based on conditions

# %%
new_df =df1[df1["RestingBP"] >= 120]
new_df
# Out:
#     Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0    40   M           ATA  ...      0.0        Up             0
# 1    49   F           NAP  ...      1.0      Flat             1
# 2    37   M           ATA  ...      0.0        Up             0
# 3    48   F           ASY  ...      1.5      Flat             1
# 4    54   M           NAP  ...      0.0        Up             0
# 5    39   M           NAP  ...      0.0        Up             0
# 6    45   F           ATA  ...      0.0        Up             0
# 8    37   M           ASY  ...      1.5      Flat             1
# 9    48   F           ATA  ...      0.0        Up             0
# 10   37   F           NAP  ...      0.0        Up             0
# 11   58   M           ATA  ...      2.0      Flat             1
# 12   39   M           ATA  ...      0.0        Up             0
# 13   49   M           ASY  ...      1.0      Flat             1
# 15   54   F           ATA  ...      1.5      Flat             0
# ...

# %%
new_df =df1[df1["ChestPainType"] == 'ATA']
new_df
# Out:
#     Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0    40   M           ATA  ...      0.0        Up             0
# 2    37   M           ATA  ...      0.0        Up             0
# 6    45   F           ATA  ...      0.0        Up             0
# 7    54   M           ATA  ...      0.0        Up             0
# 9    48   F           ATA  ...      0.0        Up             0
# 11   58   M           ATA  ...      2.0      Flat             1
# 12   39   M           ATA  ...      0.0        Up             0
# 15   54   F           ATA  ...      1.5      Flat             0
# 17   43   F           ATA  ...      0.0        Up             0
# 19   36   M           ATA  ...      3.0      Flat             1
#
# [10 rows x 12 columns]

# %%
df1.query("MaxHR>99")
# Out:
#     Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0    40   M           ATA  ...      0.0        Up             0
# 1    49   F           NAP  ...      1.0      Flat             1
# 3    48   F           ASY  ...      1.5      Flat             1
# 4    54   M           NAP  ...      0.0        Up             0
# 5    39   M           NAP  ...      0.0        Up             0
# 6    45   F           ATA  ...      0.0        Up             0
# 7    54   M           ATA  ...      0.0        Up             0
# 8    37   M           ASY  ...      1.5      Flat             1
# 9    48   F           ATA  ...      0.0        Up             0
# 10   37   F           NAP  ...      0.0        Up             0
# 12   39   M           ATA  ...      0.0        Up             0
# 13   49   M           ASY  ...      1.0      Flat             1
# 14   42   F           NAP  ...      0.0        Up             0
# 15   54   F           ATA  ...      1.5      Flat             0
# ...

# %% [markdown]
# Display the graph of the matrix

# %%
import pandas as pd
from pandas.plotting._misc import scatter_matrix
# %matplotlib inline

# %%
scatter_matrix(df1.loc[:,'Age':'HeartDisease'])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/misc.py:80: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/misc.py:81: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/misc.py:71: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[i])
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f56532eb790>,
# ...
#       dtype=object)

# %% [markdown]
# Group your dataset

# %%
df1.median()
# Out:
# Age              44.0
# RestingBP       125.0
# Cholesterol     212.5
# FastingBS         0.0
# MaxHR           142.0
# Oldpeak           0.0
# HeartDisease      0.0
# dtype: float64

# %%
df1.describe()
# Out:
#              Age   RestingBP  Cholesterol  ...       MaxHR   Oldpeak  HeartDisease
# count  20.000000   20.000000    20.000000  ...   20.000000  20.00000     20.000000
# mean   45.350000  127.450000   232.250000  ...  140.850000   0.62500      0.400000
# std     7.665885   14.680725    44.329953  ...   23.425751   0.88667      0.502625
# min    36.000000  100.000000   164.000000  ...   98.000000   0.00000      0.000000
# 25%    38.750000  120.000000   203.250000  ...  124.250000   0.00000      0.000000
# 50%    44.000000  125.000000   212.500000  ...  142.000000   0.00000      0.000000
# 75%    50.250000  138.500000   268.500000  ...  161.250000   1.12500      1.000000
# max    60.000000  160.000000   339.000000  ...  172.000000   3.00000      1.000000
#
# [8 rows x 7 columns]

# %%
df1['Age'].median()
# Out:
# 44.0

# %%
df1["ChestPainType"].value_counts()
# Out:
# ATA    10
# ASY     5
# NAP     5
# Name: ChestPainType, dtype: int64

# %% [markdown]
# Groupby

# %%
chestpain_grp = df1.groupby(["ChestPainType"])
chestpain_grp.get_group('ATA')
# Out:
#     Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0    40   M           ATA  ...      0.0        Up             0
# 2    37   M           ATA  ...      0.0        Up             0
# 6    45   F           ATA  ...      0.0        Up             0
# 7    54   M           ATA  ...      0.0        Up             0
# 9    48   F           ATA  ...      0.0        Up             0
# 11   58   M           ATA  ...      2.0      Flat             1
# 12   39   M           ATA  ...      0.0        Up             0
# 15   54   F           ATA  ...      1.5      Flat             0
# 17   43   F           ATA  ...      0.0        Up             0
# 19   36   M           ATA  ...      3.0      Flat             1
#
# [10 rows x 12 columns]

# %%
filt = df1["ChestPainType"] =="ATA"
df.loc[filt]["Sex"].value_counts()
# Out:
# M    6
# F    4
# Name: Sex, dtype: int64

# %%
chestpain_grp["Sex"].value_counts().head()
# Out:
# ChestPainType  Sex
# ASY            M      4
#                F      1
# ATA            M      6
#                F      4
# NAP            F      3
# Name: Sex, dtype: int64

# %%
chestpain_grp['Cholesterol'].agg(['median','mean'])
# Out:
#                median   mean
# ChestPainType
# ASY               214  219.8
# ATA               252  241.0
# NAP               211  227.2
